# %%
# !pip install catboost

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display
from sklearn.model_selection import cross_val_score, StratifiedKFold, GridSearchCV
from sklearn.metrics import f1_score, precision_score, recall_score, roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
import warnings
warnings.filterwarnings('ignore')

# Список файлов
files = {
    'qwen_tqa_cut.csv': 'Qwen_TruthfulQA',
    'qwen_slava_cut.csv': 'Qwen_Slava',
    'yandex_gpt_slava_answered.csv': 'YandexGPT_Slava',
    'yandex_gpt_tqa_answered.csv': 'YandexGPT_TruthfulQA',
    'gpt_slava_annotated.csv': 'ChatGPT_Slava',
    'gpt_tqa_answered.csv': 'ChatGPT_TruthfulQA',
    'giga_slava_annotated.csv': 'GigaChat_Slava',
    'giga_tqa_answered.csv': 'GigaChat_TruthfulQA'
}

feature_metrics = ['Semantic Entropy', 'EigenScore', 'SAR Score', 'NumSets', 'Self Confidence', 'Verbalized Uncertainty']

all_data = []
for file, name in files.items():
    try:
        df = pd.read_csv(file, encoding='utf-8')
        df['source'] = name
        all_data.append(df)
        print(f"✅ Loaded {file}: {len(df)} rows")
    except Exception as e:
        print(f"❌ Error loading {file}: {e}")

df_all = pd.concat(all_data, ignore_index=True)
print(f"\n📊 Total: {len(df_all)} rows")

available_features = [col for col in feature_metrics if col in df_all.columns]
print(f"✅ Available features: {available_features}")

if 'ground_truth' in df_all.columns:
    df_all['target'] = df_all['ground_truth']
    print(f"Target distribution: {df_all['target'].value_counts().to_dict()}")
else:
    print("❌ ground_truth column not found!")

df_all['model'] = df_all['source'].apply(lambda x: x.split('_')[0])
df_all['dataset'] = df_all['source'].apply(lambda x: x.split('_')[1])
# Out:
# ✅ Loaded qwen_tqa_cut.csv: 790 rows
# ✅ Loaded qwen_slava_cut.csv: 500 rows
# ✅ Loaded yandex_gpt_slava_answered.csv: 481 rows
# ✅ Loaded yandex_gpt_tqa_answered.csv: 755 rows
# ✅ Loaded gpt_slava_annotated.csv: 500 rows
# ✅ Loaded gpt_tqa_answered.csv: 785 rows
# ✅ Loaded giga_slava_annotated.csv: 500 rows
# ✅ Loaded giga_tqa_answered.csv: 761 rows
#
# 📊 Total: 5072 rows
# ✅ Available features: ['Semantic Entropy', 'EigenScore', 'SAR Score', 'NumSets', 'Self Confidence', 'Verbalized Uncertainty']
# Target distribution: {0: 4014, 1: 1058}

# %%
#МОДЕЛИ И ГИПЕРПАРАМЕТРЫ


# 1. Logistic Regression
logreg_params = {
    'C': [0.01, 0.1, 1, 10],
    'solver': ['liblinear', 'lbfgs'],
    'class_weight': ['balanced', None]
}

# 2. Random Forest
rf_params = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'class_weight': ['balanced', None]
}

# 3. Gradient Boosting
gb_params = {
    'n_estimators': [50, 100],
    'learning_rate': [0.01, 0.1],
    'max_depth': [3, 5],
    'subsample': [0.8, 1.0]
}

# 4. SVM
svm_params = {
    'C': [0.1, 1, 10],
    'kernel': ['rbf', 'linear'],
    'gamma': ['scale', 'auto'],
    'class_weight': ['balanced', None]
}

# 5. MLP (Neural Network)
mlp_params = {
    'hidden_layer_sizes': [(25,), (50,), (50, 25)],
    'activation': ['relu', 'tanh'],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate': ['constant', 'adaptive']
}

# 6. XGBoost
xgb_params = {
    'n_estimators': [50, 100],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1],
    'subsample': [0.8, 1.0],
    'colsample_bytree': [0.8, 1.0],
    'eval_metric': ['logloss']
}

# 7. CatBoost
catboost_params = {
    'iterations': [50, 100],
    'depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1],
    'l2_leaf_reg': [1, 3, 5],
    'border_count': [32, 64]
}

models_with_params = {
    'Logistic Regression': (LogisticRegression(max_iter=1000, random_state=42), logreg_params),
    'Random Forest': (RandomForestClassifier(random_state=42), rf_params),
    'Gradient Boosting': (GradientBoostingClassifier(random_state=42), gb_params),
    'SVM': (SVC(probability=True, random_state=42), svm_params),
    'MLP': (MLPClassifier(max_iter=500, random_state=42), mlp_params),
    'XGBoost': (XGBClassifier(random_state=42, use_label_encoder=False, verbosity=0), xgb_params),
    'CatBoost': (CatBoostClassifier(random_state=42, verbose=0), catboost_params)
}

# %%
def evaluate_with_gridsearch(df, dataset_name, features):
    X = df[features].fillna(df[features].mean())
    y = df['target']

    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    results = []
    for name, (model, params) in models_with_params.items():
        print(f"  Optimizing {name} on {dataset_name}...")

        # GridSearchCV
        grid_search = GridSearchCV(
            model, params,
            cv=3,
            scoring='f1',
            n_jobs=-1,
            verbose=0
        )
        grid_search.fit(X, y)

        best_model = grid_search.best_estimator_
        best_params = grid_search.best_params_

        f1_scores = []
        precision_scores = []
        recall_scores = []
        roc_scores = []

        for train_idx, test_idx in cv.split(X, y):
            X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
            y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

            model_clone = best_model.__class__(**best_model.get_params())
            model_clone.fit(X_train, y_train)
            y_pred = model_clone.predict(X_test)

            f1_scores.append(f1_score(y_test, y_pred, zero_division=0))
            precision_scores.append(precision_score(y_test, y_pred, zero_division=0))
            recall_scores.append(recall_score(y_test, y_pred, zero_division=0))

            if hasattr(model_clone, "predict_proba"):
                y_proba = model_clone.predict_proba(X_test)[:, 1]
                roc_scores.append(roc_auc_score(y_test, y_proba))
            else:
                roc_scores.append(0.5)

        results.append({
            'dataset': dataset_name,
            'model': name,
            'best_params': str(best_params),
            'f1': np.mean(f1_scores),
            'f1_std': np.std(f1_scores),
            'precision': np.mean(precision_scores),
            'precision_std': np.std(precision_scores),
            'recall': np.mean(recall_scores),
            'recall_std': np.std(recall_scores),
            'roc_auc': np.mean(roc_scores),
            'roc_auc_std': np.std(roc_scores)
        })

    return pd.DataFrame(results)

# %%
# ЗАПУСК НА ВСЕХ СРЕЗАХ

all_results = []

print("="*80)
print("1. ОТДЕЛЬНЫЕ ФАЙЛЫ (8 шт)")
print("="*80)

for file, name in files.items():
    try:
        df = pd.read_csv(file, encoding='utf-8')
        if 'ground_truth' in df.columns:
            df['target'] = df['ground_truth']
        print(f"\n📁 Processing {name} ({len(df)} samples)...")
        results = evaluate_with_gridsearch(df, name, available_features)
        all_results.append(results)
        print(f"✅ {name} completed")
    except Exception as e:
        print(f"❌ Error on {file}: {e}")

print("\n" + "="*80)
print("2. ПО ДАТАСЕТАМ (TruthfulQA vs Slava)")
print("="*80)

for dataset_name in ['TruthfulQA', 'Slava']:
    df_subset = df_all[df_all['dataset'] == dataset_name]
    if len(df_subset) > 0:
        print(f"\n📁 Processing ALL_{dataset_name} ({len(df_subset)} samples)...")
        results = evaluate_with_gridsearch(df_subset, f"ALL_{dataset_name}", available_features)
        all_results.append(results)
        print(f"✅ ALL_{dataset_name} completed")

print("\n" + "="*80)
print("3. ПО МОДЕЛЯМ")
print("="*80)

for model_name in ['Qwen', 'YandexGPT', 'ChatGPT', 'GigaChat']:
    df_subset = df_all[df_all['model'] == model_name]
    if len(df_subset) > 0:
        print(f"\n📁 Processing ALL_{model_name} ({len(df_subset)} samples)...")
        results = evaluate_with_gridsearch(df_subset, f"ALL_{model_name}", available_features)
        all_results.append(results)
        print(f"✅ ALL_{model_name} completed")

print("\n" + "="*80)
print("4. ПОЛНЫЙ ДАТАСЕТ")
print("="*80)

print(f"\n📁 Processing FULL_DATASET ({len(df_all)} samples)...")
results = evaluate_with_gridsearch(df_all, "FULL_DATASET", available_features)
all_results.append(results)
print("✅ FULL_DATASET completed")

# Объединение
df_all_results = pd.concat(all_results, ignore_index=True)
print(f"\n📊 Total evaluations: {len(df_all_results)}")
# Out:
# ================================================================================
# 1. ОТДЕЛЬНЫЕ ФАЙЛЫ (8 шт)
# ================================================================================
#
# 📁 Processing Qwen_TruthfulQA (790 samples)...
#   Optimizing Logistic Regression on Qwen_TruthfulQA...
#   Optimizing Random Forest on Qwen_TruthfulQA...
#   Optimizing Gradient Boosting on Qwen_TruthfulQA...
#   Optimizing SVM on Qwen_TruthfulQA...
#   Optimizing MLP on Qwen_TruthfulQA...
#   Optimizing XGBoost on Qwen_TruthfulQA...
#   Optimizing CatBoost on Qwen_TruthfulQA...
# ✅ Qwen_TruthfulQA completed
#
# 📁 Processing Qwen_Slava (500 samples)...
#   Optimizing Logistic Regression on Qwen_Slava...
#   Optimizing Random Forest on Qwen_Slava...
#   Optimizing Gradient Boosting on Qwen_Slava...
#   Optimizing SVM on Qwen_Slava...
#   Optimizing MLP on Qwen_Slava...
#   Optimizing XGBoost on Qwen_Slava...
#   Optimizing CatBoost on Qwen_Slava...
# ✅ Qwen_Slava completed
#
# 📁 Processing YandexGPT_Slava (481 samples)...
#   Optimizing Logistic Regression on YandexGPT_Slava...
#   Optimizing Random Forest on YandexGPT_Slava...
#   Optimizing Gradient Boosting on YandexGPT_Slava...
#   Optimizing SVM on YandexGPT_Slava...
#   Optimizing MLP on YandexGPT_Slava...
#   Optimizing XGBoost on YandexGPT_Slava...
#   Optimizing CatBoost on YandexGPT_Slava...
# ✅ YandexGPT_Slava completed
#
# 📁 Processing YandexGPT_TruthfulQA (755 samples)...
#   Optimizing Logistic Regression on YandexGPT_TruthfulQA...
#   Optimizing Random Forest on YandexGPT_TruthfulQA...
#   Optimizing Gradient Boosting on YandexGPT_TruthfulQA...
#   Optimizing SVM on YandexGPT_TruthfulQA...
#   Optimizing MLP on YandexGPT_TruthfulQA...
#   Optimizing XGBoost on YandexGPT_TruthfulQA...
#   Optimizing CatBoost on YandexGPT_TruthfulQA...
# ✅ YandexGPT_TruthfulQA completed
#
# 📁 Processing ChatGPT_Slava (500 samples)...
#   Optimizing Logistic Regression on ChatGPT_Slava...
#   Optimizing Random Forest on ChatGPT_Slava...
#   Optimizing Gradient Boosting on ChatGPT_Slava...
#   Optimizing SVM on ChatGPT_Slava...
#   Optimizing MLP on ChatGPT_Slava...
#   Optimizing XGBoost on ChatGPT_Slava...
#   Optimizing CatBoost on ChatGPT_Slava...
# ✅ ChatGPT_Slava completed
#
# 📁 Processing ChatGPT_TruthfulQA (785 samples)...
#   Optimizing Logistic Regression on ChatGPT_TruthfulQA...
#   Optimizing Random Forest on ChatGPT_TruthfulQA...
#   Optimizing Gradient Boosting on ChatGPT_TruthfulQA...
#   Optimizing SVM on ChatGPT_TruthfulQA...
#   Optimizing MLP on ChatGPT_TruthfulQA...
#   Optimizing XGBoost on ChatGPT_TruthfulQA...
#   Optimizing CatBoost on ChatGPT_TruthfulQA...
# ✅ ChatGPT_TruthfulQA completed
#
# 📁 Processing GigaChat_Slava (500 samples)...
#   Optimizing Logistic Regression on GigaChat_Slava...
#   Optimizing Random Forest on GigaChat_Slava...
#   Optimizing Gradient Boosting on GigaChat_Slava...
#   Optimizing SVM on GigaChat_Slava...
#   Optimizing MLP on GigaChat_Slava...
#   Optimizing XGBoost on GigaChat_Slava...
#   Optimizing CatBoost on GigaChat_Slava...
# ✅ GigaChat_Slava completed
#
# 📁 Processing GigaChat_TruthfulQA (761 samples)...
#   Optimizing Logistic Regression on GigaChat_TruthfulQA...
#   Optimizing Random Forest on GigaChat_TruthfulQA...
#   Optimizing Gradient Boosting on GigaChat_TruthfulQA...
#   Optimizing SVM on GigaChat_TruthfulQA...
#   Optimizing MLP on GigaChat_TruthfulQA...
#   Optimizing XGBoost on GigaChat_TruthfulQA...
#   Optimizing CatBoost on GigaChat_TruthfulQA...
# ✅ GigaChat_TruthfulQA completed
#
# ================================================================================
# 2. ПО ДАТАСЕТАМ (TruthfulQA vs Slava)
# ================================================================================
#
# 📁 Processing ALL_TruthfulQA (3091 samples)...
#   Optimizing Logistic Regression on ALL_TruthfulQA...
#   Optimizing Random Forest on ALL_TruthfulQA...
#   Optimizing Gradient Boosting on ALL_TruthfulQA...
#   Optimizing SVM on ALL_TruthfulQA...
#   Optimizing MLP on ALL_TruthfulQA...
#   Optimizing XGBoost on ALL_TruthfulQA...
#   Optimizing CatBoost on ALL_TruthfulQA...
# ✅ ALL_TruthfulQA completed
#
# 📁 Processing ALL_Slava (1981 samples)...
#   Optimizing Logistic Regression on ALL_Slava...
#   Optimizing Random Forest on ALL_Slava...
#   Optimizing Gradient Boosting on ALL_Slava...
#   Optimizing SVM on ALL_Slava...
#   Optimizing MLP on ALL_Slava...
#   Optimizing XGBoost on ALL_Slava...
#   Optimizing CatBoost on ALL_Slava...
# ✅ ALL_Slava completed
#
# ================================================================================
# 3. ПО МОДЕЛЯМ
# ================================================================================
#
# 📁 Processing ALL_Qwen (1290 samples)...
#   Optimizing Logistic Regression on ALL_Qwen...
#   Optimizing Random Forest on ALL_Qwen...
#   Optimizing Gradient Boosting on ALL_Qwen...
#   Optimizing SVM on ALL_Qwen...
#   Optimizing MLP on ALL_Qwen...
#   Optimizing XGBoost on ALL_Qwen...
#   Optimizing CatBoost on ALL_Qwen...
# ✅ ALL_Qwen completed
#
# 📁 Processing ALL_YandexGPT (1236 samples)...
#   Optimizing Logistic Regression on ALL_YandexGPT...
#   Optimizing Random Forest on ALL_YandexGPT...
#   Optimizing Gradient Boosting on ALL_YandexGPT...
#   Optimizing SVM on ALL_YandexGPT...
#   Optimizing MLP on ALL_YandexGPT...
#   Optimizing XGBoost on ALL_YandexGPT...
#   Optimizing CatBoost on ALL_YandexGPT...
# ✅ ALL_YandexGPT completed
#
# 📁 Processing ALL_ChatGPT (1285 samples)...
#   Optimizing Logistic Regression on ALL_ChatGPT...
#   Optimizing Random Forest on ALL_ChatGPT...
#   Optimizing Gradient Boosting on ALL_ChatGPT...
#   Optimizing SVM on ALL_ChatGPT...
#   Optimizing MLP on ALL_ChatGPT...
#   Optimizing XGBoost on ALL_ChatGPT...
#   Optimizing CatBoost on ALL_ChatGPT...
# ✅ ALL_ChatGPT completed
#
# 📁 Processing ALL_GigaChat (1261 samples)...
#   Optimizing Logistic Regression on ALL_GigaChat...
#   Optimizing Random Forest on ALL_GigaChat...
#   Optimizing Gradient Boosting on ALL_GigaChat...
#   Optimizing SVM on ALL_GigaChat...
#   Optimizing MLP on ALL_GigaChat...
#   Optimizing XGBoost on ALL_GigaChat...
#   Optimizing CatBoost on ALL_GigaChat...
# ✅ ALL_GigaChat completed
#
# ================================================================================
# 4. ПОЛНЫЙ ДАТАСЕТ
# ================================================================================
#
# 📁 Processing FULL_DATASET (5072 samples)...
#   Optimizing Logistic Regression on FULL_DATASET...
#   Optimizing Random Forest on FULL_DATASET...
#   Optimizing Gradient Boosting on FULL_DATASET...
#   Optimizing SVM on FULL_DATASET...
#   Optimizing MLP on FULL_DATASET...
#   Optimizing XGBoost on FULL_DATASET...
#   Optimizing CatBoost on FULL_DATASET...
# ✅ FULL_DATASET completed
#
# 📊 Total evaluations: 105

# %%
#Resutls

print("="*80)
print("ТАБЛИЦЫ ПО КАЖДОМУ СРЕЗУ")
print("="*80)

def create_table(df, slice_names, title):
    df_subset = df[df['dataset'].isin(slice_names)]
    if df_subset.empty:
        return None
    table = df_subset[['dataset', 'model', 'f1', 'precision', 'recall', 'roc_auc']].copy()
    table = table.round(4)
    table = table.sort_values(['dataset', 'f1'], ascending=[True, False])
    print(f"\n{title}")
    display(table)
    return table

# Таблица 1: Отдельные файлы
individual_names = list(files.values())
table1 = create_table(df_all_results, individual_names, "📊 ТАБЛИЦА 1: ОТДЕЛЬНЫЕ ФАЙЛЫ")

# Таблица 2: По датасетам
dataset_names = [d for d in df_all_results['dataset'].unique() if d.startswith('ALL_TruthfulQA') or d.startswith('ALL_Slava')]
table2 = create_table(df_all_results, dataset_names, "📊 ТАБЛИЦА 2: ПО ДАТАСЕТАМ")

# Таблица 3: По моделям
model_names = [d for d in df_all_results['dataset'].unique() if d.startswith('ALL_Qwen') or d.startswith('ALL_YandexGPT') or d.startswith('ALL_ChatGPT') or d.startswith('ALL_GigaChat')]
table3 = create_table(df_all_results, model_names, "📊 ТАБЛИЦА 3: ПО МОДЕЛЯМ")

# Таблица 4: Полный датасет
table4 = create_table(df_all_results, ['FULL_DATASET'], "📊 ТАБЛИЦА 4: ПОЛНЫЙ ДАТАСЕТ")

# Сохранение
if table1 is not None: table1.to_csv('table1_individual.csv', index=False)
if table2 is not None: table2.to_csv('table2_by_dataset.csv', index=False)
if table3 is not None: table3.to_csv('table3_by_model.csv', index=False)
if table4 is not None: table4.to_csv('table4_full.csv', index=False)
# Out:
# ================================================================================
# ТАБЛИЦЫ ПО КАЖДОМУ СРЕЗУ
# ================================================================================
#
# 📊 ТАБЛИЦА 1: ОТДЕЛЬНЫЕ ФАЙЛЫ
#                  dataset                model      f1  precision  recall  \
# 28         ChatGPT_Slava  Logistic Regression  0.3472     0.2321  0.7000
# 31         ChatGPT_Slava                  SVM  0.3398     0.2299  0.6750
# 30         ChatGPT_Slava    Gradient Boosting  0.1831     0.2386  0.1500
# 29         ChatGPT_Slava        Random Forest  0.1564     0.1697  0.1500
# 33         ChatGPT_Slava              XGBoost  0.1133     0.2500  0.0750
# 32         ChatGPT_Slava                  MLP  0.0844     0.3000  0.0500
# 34         ChatGPT_Slava             CatBoost  0.0800     0.2000  0.0500
# 38    ChatGPT_TruthfulQA                  SVM  0.4568     0.3622  0.6252
# 36    ChatGPT_TruthfulQA        Random Forest  0.4536     0.4487  0.4629
# 37    ChatGPT_TruthfulQA    Gradient Boosting  0.4331     0.7129  0.3171
# 35    ChatGPT_TruthfulQA  Logistic Regression  0.4298     0.3537  0.5476
# 40    ChatGPT_TruthfulQA              XGBoost  0.4115     0.7145  0.2981
# 41    ChatGPT_TruthfulQA             CatBoost  0.4109     0.7004  0.3071
# 39    ChatGPT_TruthfulQA                  MLP  0.3625     0.6326  0.2595
# 42        GigaChat_Slava  Logistic Regression  0.1635     0.1574  0.2583
# 45        GigaChat_Slava                  SVM  0.0784     0.0967  0.0694
# 43        GigaChat_Slava        Random Forest  0.0000     0.0000  0.0000
# 44        GigaChat_Slava    Gradient Boosting  0.0000     0.0000  0.0000
# 46        GigaChat_Slava                  MLP  0.0000     0.0000  0.0000
# 47        GigaChat_Slava              XGBoost  0.0000     0.0000  0.0000
# 48        GigaChat_Slava             CatBoost  0.0000     0.0000  0.0000
# 49   GigaChat_TruthfulQA  Logistic Regression  0.2534     0.1687  0.5114
# 50   GigaChat_TruthfulQA        Random Forest  0.0822     0.1348  0.0601
# 51   GigaChat_TruthfulQA    Gradient Boosting  0.0751     0.1351  0.0530
# 52   GigaChat_TruthfulQA                  SVM  0.0600     0.0353  0.2000
# 54   GigaChat_TruthfulQA              XGBoost  0.0346     0.0722  0.0228
# 53   GigaChat_TruthfulQA                  MLP  0.0000     0.0000  0.0000
# 55   GigaChat_TruthfulQA             CatBoost  0.0000     0.0000  0.0000
# 12            Qwen_Slava              XGBoost  0.6848     0.5737  0.8495
# 10            Qwen_Slava                  SVM  0.6825     0.5180  1.0000
# 13            Qwen_Slava             CatBoost  0.6813     0.5781  0.8301
# 7             Qwen_Slava  Logistic Regression  0.6808     0.5207  0.9846
# 9             Qwen_Slava    Gradient Boosting  0.6760     0.5761  0.8186
# 11            Qwen_Slava                  MLP  0.6306     0.6124  0.6523
# 8             Qwen_Slava        Random Forest  0.5501     0.5548  0.5519
# 3        Qwen_TruthfulQA                  SVM  0.5755     0.5258  0.6360
# 0        Qwen_TruthfulQA  Logistic Regression  0.5678     0.5327  0.6094
# 6        Qwen_TruthfulQA             CatBoost  0.5043     0.5459  0.4731
# 1        Qwen_TruthfulQA        Random Forest  0.4851     0.4885  0.4822
# 5        Qwen_TruthfulQA              XGBoost  0.4710     0.5376  0.4201
# 2        Qwen_TruthfulQA    Gradient Boosting  0.4665     0.4852  0.4499
# 4        Qwen_TruthfulQA                  MLP  0.4092     0.5402  0.3425
# 15       YandexGPT_Slava        Random Forest  0.2475     0.2094  0.3306
# 14       YandexGPT_Slava  Logistic Regression  0.2049     0.1797  0.2389
# 17       YandexGPT_Slava                  SVM  0.1953     0.2013  0.1917
# 16       YandexGPT_Slava    Gradient Boosting  0.1927     0.3133  0.1417
# 19       YandexGPT_Slava              XGBoost  0.0971     0.2667  0.0722
# 20       YandexGPT_Slava             CatBoost  0.0400     0.2000  0.0222
# 18       YandexGPT_Slava                  MLP  0.0000     0.0000  0.0000
# 23  YandexGPT_TruthfulQA    Gradient Boosting  0.3569     0.4547  0.2952
# 21  YandexGPT_TruthfulQA  Logistic Regression  0.3372     0.2427  0.5538
# 26  YandexGPT_TruthfulQA              XGBoost  0.3331     0.5405  0.2462
# 22  YandexGPT_TruthfulQA        Random Forest  0.3131     0.3970  0.2657
# 24  YandexGPT_TruthfulQA                  SVM  0.3113     0.2249  0.5138
# 27  YandexGPT_TruthfulQA             CatBoost  0.3013     0.5913  0.2067
# 25  YandexGPT_TruthfulQA                  MLP  0.0729     0.5333  0.0400
#
#     roc_auc
# 28   0.7852
# 31   0.7874
# 30   0.6793
# 29   0.6716
# 33   0.7385
# 32   0.7811
# 34   0.7640
# 38   0.8067
# 36   0.7957
# 37   0.7998
# 35   0.8011
# 40   0.8062
# 41   0.8229
# 39   0.8030
# 42   0.5223
# 45   0.4273
# 43   0.4635
# 44   0.4644
# 46   0.5527
# 47   0.4938
# 48   0.5274
# 49   0.4803
# 50   0.5150
# 51   0.5249
# 52   0.5128
# 54   0.4870
# 53   0.5293
# 55   0.5184
# 12   0.5905
# 10   0.4557
# 13   0.6291
# 7    0.5732
# 9    0.6119
# 11   0.6430
# 8    0.5536
# 3    0.6375
# 0    0.6378
# 6    0.6323
# 1    0.5816
# 5    0.6101
# 2    0.5718
# 4    0.6386
# 15   0.5750
# 14   0.6317
# 17   0.6955
# 16   0.6031
# 19   0.6557
# 20   0.7046
# 18   0.6966
# 23   0.7264
# 21   0.6682
# 26   0.7321
# 22   0.6834
# 24   0.6385
# 27   0.6819
# 25   0.6896
# 📊 ТАБЛИЦА 2: ПО ДАТАСЕТАМ
#            dataset                model      f1  precision  recall  roc_auc
# 63       ALL_Slava  Logistic Regression  0.5533     0.4466  0.7293   0.7931
# 66       ALL_Slava                  SVM  0.5508     0.4385  0.7423   0.7990
# 64       ALL_Slava        Random Forest  0.5192     0.4844  0.5624   0.7896
# 68       ALL_Slava              XGBoost  0.4648     0.5818  0.3907   0.7943
# 69       ALL_Slava             CatBoost  0.4614     0.5827  0.3854   0.8152
# 65       ALL_Slava    Gradient Boosting  0.4388     0.5634  0.3620   0.8098
# 67       ALL_Slava                  MLP  0.3974     0.5496  0.3336   0.7966
# 57  ALL_TruthfulQA        Random Forest  0.4653     0.4243  0.5163   0.7282
# 56  ALL_TruthfulQA  Logistic Regression  0.4615     0.3685  0.6188   0.6882
# 59  ALL_TruthfulQA                  SVM  0.4492     0.3768  0.5565   0.7081
# 61  ALL_TruthfulQA              XGBoost  0.3049     0.4575  0.2314   0.7203
# 58  ALL_TruthfulQA    Gradient Boosting  0.2849     0.4560  0.2077   0.7230
# 62  ALL_TruthfulQA             CatBoost  0.2178     0.5287  0.1379   0.7486
# 60  ALL_TruthfulQA                  MLP  0.1765     0.6082  0.1038   0.7341
# 📊 ТАБЛИЦА 3: ПО МОДЕЛЯМ
#           dataset                model      f1  precision  recall  roc_auc
# 84    ALL_ChatGPT  Logistic Regression  0.4064     0.3110  0.5901   0.7341
# 87    ALL_ChatGPT                  SVM  0.3971     0.3041  0.5766   0.7403
# 88    ALL_ChatGPT                  MLP  0.2872     0.6084  0.1948   0.7518
# 85    ALL_ChatGPT        Random Forest  0.2688     0.5183  0.1879   0.7307
# 86    ALL_ChatGPT    Gradient Boosting  0.2669     0.4205  0.2022   0.7332
# 89    ALL_ChatGPT              XGBoost  0.2468     0.4038  0.1815   0.7118
# 90    ALL_ChatGPT             CatBoost  0.2450     0.5994  0.1672   0.7766
# 94   ALL_GigaChat                  SVM  0.2691     0.1787  0.5464   0.5881
# 91   ALL_GigaChat  Logistic Regression  0.2670     0.1769  0.5459   0.5891
# 92   ALL_GigaChat        Random Forest  0.1469     0.1796  0.1319   0.5203
# 93   ALL_GigaChat    Gradient Boosting  0.0803     0.1889  0.0514   0.5316
# 96   ALL_GigaChat              XGBoost  0.0216     0.2667  0.0114   0.5120
# 95   ALL_GigaChat                  MLP  0.0000     0.0000  0.0000   0.5929
# 97   ALL_GigaChat             CatBoost  0.0000     0.0000  0.0000   0.5748
# 73       ALL_Qwen                  SVM  0.5710     0.5412  0.6047   0.6154
# 70       ALL_Qwen  Logistic Regression  0.5654     0.5405  0.5930   0.6181
# 76       ALL_Qwen             CatBoost  0.5565     0.5740  0.5411   0.6202
# 72       ALL_Qwen    Gradient Boosting  0.5127     0.5374  0.4908   0.5782
# 71       ALL_Qwen        Random Forest  0.5102     0.4984  0.5227   0.5519
# 75       ALL_Qwen              XGBoost  0.5019     0.5257  0.4808   0.5714
# 74       ALL_Qwen                  MLP  0.4963     0.5502  0.4623   0.6219
# 77  ALL_YandexGPT  Logistic Regression  0.2643     0.2295  0.3165   0.6078
# 80  ALL_YandexGPT                  SVM  0.2471     0.2370  0.2663   0.5837
# 78  ALL_YandexGPT        Random Forest  0.2428     0.2708  0.2236   0.6434
# 79  ALL_YandexGPT    Gradient Boosting  0.2034     0.5889  0.1264   0.6682
# 82  ALL_YandexGPT              XGBoost  0.1778     0.4783  0.1121   0.7019
# 83  ALL_YandexGPT             CatBoost  0.1673     0.6733  0.0985   0.6936
# 81  ALL_YandexGPT                  MLP  0.1158     0.7833  0.0633   0.6085
# 📊 ТАБЛИЦА 4: ПОЛНЫЙ ДАТАСЕТ
#           dataset                model      f1  precision  recall  roc_auc
# 98   FULL_DATASET  Logistic Regression  0.4860     0.3754  0.6900   0.7260
# 99   FULL_DATASET        Random Forest  0.4743     0.4169  0.5521   0.7362
# 101  FULL_DATASET                  SVM  0.4699     0.3832  0.6088   0.7305
# 103  FULL_DATASET              XGBoost  0.3321     0.4634  0.2599   0.7377
# 100  FULL_DATASET    Gradient Boosting  0.2968     0.4732  0.2174   0.7430
# 104  FULL_DATASET             CatBoost  0.2128     0.5336  0.1342   0.7583
# 102  FULL_DATASET                  MLP  0.1573     0.5285  0.0964   0.7352
